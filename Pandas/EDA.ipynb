# %%
import pandas as pd

# %%
df = pd.read_csv("E:\playground\python_playgroung_codes\Data_Science\Pandas\Training_Data(CSV-file)\weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df1 = pd.read_csv("E:\playground\python_playgroung_codes\Data_Science\Pandas\Training_Data(CSV-file)\infolimpioavanzadoTarget.csv")

# %%
df1
# Out:
#             date       open       high        low      close   adjclose  \
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000  17.760000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000  17.660000
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001  16.950001
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000  16.170000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000  15.710000
# ...          ...        ...        ...        ...        ...        ...
# 7776  2022-12-23  23.250000  23.540001  23.250000  23.290001  22.699928
# 7777  2022-12-27  23.350000  23.610001  23.250000  23.350000  22.758406
# 7778  2022-12-28  23.450001  23.570000  23.219999  23.350000  22.758406
# 7779  2022-12-29  23.330000  23.740000  23.330000  23.610001  23.011820
# 7780  2022-12-30  23.680000  23.760000  23.610001  23.610001  23.011820
#
#       volume ticker  RSIadjclose15  RSIvolume15  ...    high-15       K-15  \
# ...

# %%
df1["high"].max()
# Out:
# 799.3599853515625

# %%
df1["high"].min()
# Out:
# 0.4350000023841858

# %%
df["outlook"].max()   #max will five the max frequence of col
# Out:
# 'sunny'

# %%
df["outlook"].min()  #min will give the min freq of the col
# Out:
# 'overcast'

# %%
df["outlook"] == "rainy"   # for each row when the value of the col match with the object it return true alse false
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: outlook, dtype: bool

# %%
df[df["outlook"]=="rainy"]
# Out:
#   outlook temperature humidity  windy play
# 4   rainy        mild     high  False  yes
# 5   rainy        cool   normal  False  yes
# 6   rainy        cool   normal   True   no
# 7   rainy        mild   normal  False  yes
# 8   rainy        mild     high   True   no

# %%
df["outlook"] = "rainy"

# %%
df
# Out:
#    outlook temperature humidity  windy play
# 0    rainy         hot     high  False  yes
# 1    rainy        cool   normal   True  yes
# 2    rainy        mild     high   True  yes
# 3    rainy         hot   normal  False  yes
# 4    rainy        mild     high  False  yes
# 5    rainy        cool   normal  False  yes
# 6    rainy        cool   normal   True   no
# 7    rainy        mild   normal  False  yes
# 8    rainy        mild     high   True   no
# 9    rainy         hot     high  False   no
# 10   rainy         hot     high   True   no
# 11   rainy        mild     high  False   no
# 12   rainy        cool   normal  False  yes
# 13   rainy        mild   normal   True  yes

# %%
df1
# Out:
#             date       open       high        low      close   adjclose  \
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000  17.760000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000  17.660000
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001  16.950001
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000  16.170000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000  15.710000
# ...          ...        ...        ...        ...        ...        ...
# 7776  2022-12-23  23.250000  23.540001  23.250000  23.290001  22.699928
# 7777  2022-12-27  23.350000  23.610001  23.250000  23.350000  22.758406
# 7778  2022-12-28  23.450001  23.570000  23.219999  23.350000  22.758406
# 7779  2022-12-29  23.330000  23.740000  23.330000  23.610001  23.011820
# 7780  2022-12-30  23.680000  23.760000  23.610001  23.610001  23.011820
#
#       volume ticker  RSIadjclose15  RSIvolume15  ...    high-15       K-15  \
# ...

# %%
df = pd.read_csv("Training_Data(CSV-file)/weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df[df["windy"]]
# Out:
#      outlook temperature humidity  windy play
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 6      rainy        cool   normal   True   no
# 8      rainy        mild     high   True   no
# 10     sunny         hot     high   True   no
# 13     sunny        mild   normal   True  yes

# %%
df[df["windy"]==False]
df[~df["windy"]]
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 7      rainy        mild   normal  False  yes
# 9      sunny         hot     high  False   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes

# %%
# df[df["outlook"] == "overcast"]
df[df["outlook"] == "overcast"] = 100
df[df["outlook"] == "sunny"] = 1
df[df["outlook"] == "rainy"] = 50
df["outlook"]
# Out:
# 0     100
# 1     100
# 2     100
# 3     100
# 4      50
# 5      50
# 6      50
# 7      50
# 8      50
# 9       1
# 10      1
# 11      1
# 12      1
# 13      1
# Name: outlook, dtype: object

# %%
df["outlook"].max()
# Out:
# 100

# %%
df["outlook"].min()
# Out:
# 1

# %%
df = pd.read_csv("Training_Data(CSV-file)/weather.csv")

# %%
df["outlook"].max()
# Out:
# 'sunny'

# %%
df["outlook"].min()
# Out:
# 'overcast'

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df["outlook"][df["temperature"] == "hot"]    # `df["temperature"] == "hot"` will give the true index when temp was hot and `df["outlook"][df["temperature"] == "hot"]` will give all the outlooks when the temp was hot
# Out:
# 0     overcast
# 3     overcast
# 9        sunny
# 10       sunny
# Name: outlook, dtype: object

# %%
df["outlook"][df["temperature"] == "hot"] == "sunny"   # it will give all bool true and false for all index where temp was hot and outlook was sunny
# Out:
# 0     False
# 3     False
# 9      True
# 10     True
# Name: outlook, dtype: bool

# %%
df[df["outlook"][df["temperature"] == "hot"] == "sunny"]
df["outlook"][df["outlook"][df["temperature"] == "hot"] == "sunny"]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df["outlook"][df["outlook"][df["temperature"] == "hot"] == "sunny"]
#
# File e:\playground\python_playgroung_codes\Data_Science\Pandas\pandas-venv\Lib\site-packages\pandas\core\series.py:1149, in Series.__getitem__(self, key)
#    1146     return self._getitem_slice(key)
#    1148 if com.is_bool_indexer(key):
# -> 1149     key = check_bool_indexer(self.index, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
#
# File e:\playground\python_playgroung_codes\Data_Science\Pandas\pandas-venv\Lib\site-packages\pandas\core\indexing.py:2662, in check_bool_indexer(index, key)
#    2660 indexer = result.index.get_indexer_for(index)
#    2661 if -1 in indexer:
# -> 2662     raise IndexingError(
#    2663         "Unalignable boolean Series provided as "
# ...

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %% [markdown]
# Starting with new CSV file as dataframe(df) -> "training_data(csv-file)/nyc_weather"

# %% [markdown]
# **Data Munging/Data Wrangling**

# %%
import pandas as pd

# %%
df = pd.read_csv("Training_Data(CSV-file)/nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df["Temperature"].max()
# Out:
# 50

# %%
df["Temperature"].min()
# Out:
# 20

# %%
df["Events"] == "Rain"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# Name: Events, dtype: bool

# %%
df["EST"][df["Events"] == "Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df.count()
# Out:
# EST                     31
# Temperature             31
# DewPoint                31
# Humidity                31
# Sea Level PressureIn    31
# VisibilityMiles         31
# WindSpeedMPH            28
# PrecipitationIn         31
# CloudCover              31
# Events                   9
# WindDirDegrees          31
# dtype: int64

# %%
df["WindSpeedMPH"].count()
# Out:
# 28

# %%
df["WindSpeedMPH"].sum()
# Out:
# 193.0

# %%
df["WindSpeedMPH"].mean()
# Out:
# 6.892857142857143

# %%
193/28
# Out:
# 6.892857142857143

# %%
df["WindSpeedMPH"].fillna(0)
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      0.0
# 10     0.0
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     0.0
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df["WindSpeedMPH"].count()
# Out:
# 28

# %%
df["WindSpeedMPH"].sum()
# Out:
# 193.0

# %%
df["WindSpeedMPH"].mean()
# Out:
# 6.892857142857143

# %%
df = pd.read_csv("Training_Data(CSV-file)/nyc_weather.csv")

# %%
df["WindSpeedMPH"]
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      NaN
# 10     NaN
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     NaN
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df["WindSpeedMPH"].fillna(0, inplace=True)

# %%
df["WindSpeedMPH"]
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      0.0
# 10     0.0
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     0.0
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df["WindSpeedMPH"].count()
# Out:
# 31

# %%
df["WindSpeedMPH"].sum()
# Out:
# 193.0

# %%
df["WindSpeedMPH"].mean()
# Out:
# 6.225806451612903

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.225806    3.129032      247.129032
# std           1.939405      3.422569    2.629853       92.308086
# min           1.000000      0.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df["WindSpeedMPH"].drop(0, inplace=True)

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.225806    3.129032      247.129032
# std           1.939405      3.422569    2.629853       92.308086
# min           1.000000      0.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df["WindSpeedMPH"]
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      0.0
# 10     0.0
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     0.0
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df["WindSpeedMPH"][df["Humidity"] > df["Humidity"].mean()]
# Out:
# 0      8.0
# 7      4.0
# 8      8.0
# 9      0.0
# 11     6.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df["Humidity"][df["Humidity"] > df["Humidity"].mean()]
# Out:
# 0     52
# 7     64
# 8     77
# 9     71
# 11    53
# 14    62
# 15    70
# 16    66
# 17    53
# 22    78
# 23    53
# 24    54
# 25    56
# 30    52
# Name: Humidity, dtype: int64

# %%
df[df["Humidity"] > df["Humidity"].mean()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# ...

# %%
import pandas as pd
df[df["Humidity"] <= df["Humidity"].mean()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 10  1/11/2016           33         8        37                 29.92
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# ...

# %%
df["Humidity"].mean()
# Out:
# 51.67741935483871

# %%
df["Humidity"][df["Humidity"] <= df["Humidity"]] = df["Humidity"].mean()
# Out:
# C:\Users\avara\AppData\Local\Temp\ipykernel_11604\4283971705.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Humidity"][df["Humidity"] <= df["Humidity"]] = df["Humidity"].mean()
# ...
