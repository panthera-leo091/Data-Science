# %%
import pandas as pd

# %%
df = pd.read_csv("Training_Data(CSV-file)/weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
weathers = {
    "outlook": ["overcast", "rainy", "sunny"],
    "temprature": ["hot", "mild", "cool"],
    "humidity": ["high", "high", "normal"],
    "windy": ["True", "False", "False"],
    "play": ["yes", "no", "yes"]
}

# %%
df1 = pd.DataFrame(weathers)

# %%
df1
# Out:
#     outlook temprature humidity  windy play
# 0  overcast        hot     high   True  yes
# 1     rainy       mild     high  False   no
# 2     sunny       cool   normal  False  yes

# %%
del df1

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df = pd.read_csv("Training_Data(CSV-file)/weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (14, 5)

# %%
row, col = df.shape

# %%
row
# Out:
# 14

# %%
col
# Out:
# 5

# %% [markdown]
# Day 1

# %%
import pandas as pd

# %%
df = pd.read_csv("training_data(CSV-file)/weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.shape
# Out:
# (14, 5)

# %%
row, col = df.shape

# %%
row
# Out:
# 14

# %%
col
# Out:
# 5

# %%
df.head() # print starting 5 rows
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes

# %%
df.tail()   # print end 5 rows
# Out:
#    outlook temperature humidity  windy play
# 9    sunny         hot     high  False   no
# 10   sunny         hot     high   True   no
# 11   sunny        mild     high  False   no
# 12   sunny        cool   normal  False  yes
# 13   sunny        mild   normal   True  yes

# %%
df.head(2)   # print initial 2 rows
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes

# %%
df.head(10)
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes
# 5     rainy        cool   normal  False  yes
# 6     rainy        cool   normal   True   no
# 7     rainy        mild   normal  False  yes
# 8     rainy        mild     high   True   no
# 9     sunny         hot     high  False   no

# %%
df.tail(8)
# Out:
#    outlook temperature humidity  windy play
# 6    rainy        cool   normal   True   no
# 7    rainy        mild   normal  False  yes
# 8    rainy        mild     high   True   no
# 9    sunny         hot     high  False   no
# 10   sunny         hot     high   True   no
# 11   sunny        mild     high  False   no
# 12   sunny        cool   normal  False  yes
# 13   sunny        mild   normal   True  yes

# %%
df.tail(1)
# Out:
#    outlook temperature humidity  windy play
# 13   sunny        mild   normal   True  yes

# %%
df[2:6]   # range from [1, 6) as slicing from row index 2nd to 5th but dosn't inclue 6th index
# Out:
#     outlook temperature humidity  windy play
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes
# 5     rainy        cool   normal  False  yes

# %%
df[:6]
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes
# 5     rainy        cool   normal  False  yes

# %%
df[:]
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.columns
# Out:
# Index(['outlook', 'temperature', 'humidity', 'windy', 'play'], dtype='object')

# %%
df.outlook
# Out:
# 0     overcast
# 1     overcast
# 2     overcast
# 3     overcast
# 4        rainy
# 5        rainy
# 6        rainy
# 7        rainy
# 8        rainy
# 9        sunny
# 10       sunny
# 11       sunny
# 12       sunny
# 13       sunny
# Name: outlook, dtype: object

# %%
df["outlook"]
# Out:
# 0     overcast
# 1     overcast
# 2     overcast
# 3     overcast
# 4        rainy
# 5        rainy
# 6        rainy
# 7        rainy
# 8        rainy
# 9        sunny
# 10       sunny
# 11       sunny
# 12       sunny
# 13       sunny
# Name: outlook, dtype: object

# %%
type(df.outlook)
# Out:
# pandas.core.series.Series

# %%
type(df["humidity"])
# Out:
# pandas.core.series.Series

# %%
df[["outlook", "humidity"]]
# Out:
#      outlook humidity
# 0   overcast     high
# 1   overcast   normal
# 2   overcast     high
# 3   overcast   normal
# 4      rainy     high
# 5      rainy   normal
# 6      rainy   normal
# 7      rainy   normal
# 8      rainy     high
# 9      sunny     high
# 10     sunny     high
# 11     sunny     high
# 12     sunny   normal
# 13     sunny   normal

# %%
df.columns
# Out:
# Index(['outlook', 'temperature', 'humidity', 'windy', 'play'], dtype='object')

# %%
df[["outlook", "humidity", "play"]]
# Out:
#      outlook humidity play
# 0   overcast     high  yes
# 1   overcast   normal  yes
# 2   overcast     high  yes
# 3   overcast   normal  yes
# 4      rainy     high  yes
# 5      rainy   normal  yes
# 6      rainy   normal   no
# 7      rainy   normal  yes
# 8      rainy     high   no
# 9      sunny     high   no
# 10     sunny     high   no
# 11     sunny     high   no
# 12     sunny   normal  yes
# 13     sunny   normal  yes

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df["play"].max()
# Out:
# 'yes'

# %%
# remamber that max() will print the max value of the objects in a col if the col contain int values else it will print max freq in the col

# %%
df["play"].std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\playground\python_playgroung_codes\Data_Science\Pandas\pandas-venv\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File e:\playground\python_playgroung_codes\Data_Science\Pandas\pandas-venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# ...

# %%
test1 = {
    "col1": ["r11", "r12", "r13"],
    "col2": ["r21", "r22", "r23"],
    "col3": ["r31", "r32", "r33"]
}

# %%
test1
# Out:
# {'col1': ['r11', 'r12', 'r13'],
#  'col2': ['r21', 'r22', 'r23'],
#  'col3': ['r31', 'r32', 'r33']}

# %%
del test1

# %%
test = {
    "temp": [12, 98, 64, 93, 98, 64, 73, 36, 64, 27],
    "weather": ["cold", "rainy", "sunny", "sunny", "cold", "rainy", "cold", "rainy", "sunny", "sunny"]
}

# %%
df1 = pd.DataFrame(test)

# %%
df1
# Out:
#    temp weather
# 0    12    cold
# 1    98   rainy
# 2    64   sunny
# 3    93   sunny
# 4    98    cold
# 5    64   rainy
# 6    73    cold
# 7    36   rainy
# 8    64   sunny
# 9    27   sunny

# %%
df1.temp.std()
# Out:
# 29.960900446340986

# %%
df1["temp"].sum()
# Out:
# 629

# %%
df1["temp"].count()
# Out:
# 10

# %%
df1["temp"].mean()
# Out:
# 62.9

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df1["temp"].std()
# Out:
# 29.960900446340986

# %%
df.describe()
# Out:
#        outlook temperature humidity  windy play
# count       14          14       14     14   14
# unique       3           3        2      2    2
# top      rainy        mild     high  False  yes
# freq         5           6        7      8    9

# %%
df1.describe()
# Out:
#           temp
# count  10.0000
# mean   62.9000
# std    29.9609
# min    12.0000
# 25%    43.0000
# 50%    64.0000
# 75%    88.0000
# max    98.0000

# %%
df1.columns
# Out:
# Index(['temp', 'weather'], dtype='object')

# %%
df1["weather"].describe()
# Out:
# count        10
# unique        3
# top       sunny
# freq          4
# Name: weather, dtype: object

# %%
df1[df1["temp"] >= 43]
# Out:
#    temp weather
# 1    98   rainy
# 2    64   sunny
# 3    93   sunny
# 4    98    cold
# 5    64   rainy
# 6    73    cold
# 8    64   sunny

# %%
df1[df1["temp"] == df1.temp.max()]     # it will only print the row where temp was max
# Out:
#    temp weather
# 1    98   rainy
# 4    98    cold

# %%
df1.weather[df1["temp"] == df1.temp.min()]
# Out:
# 0    cold
# Name: weather, dtype: object

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df[ ["windy", "play"] ][df["outlook"] == df["outlook"].max()]
# Out:
#     windy play
# 9   False   no
# 10   True   no
# 11  False   no
# 12  False  yes
# 13   True  yes

# %%
df["outlook"][df["outlook"] == df["outlook"].max()]
# Out:
# 9     sunny
# 10    sunny
# 11    sunny
# 12    sunny
# 13    sunny
# Name: outlook, dtype: object

# %%
df1["temp"].median()
# Out:
# 64.0

# %%
df1["temp"].std()
# Out:
# 29.960900446340986

# %%
df1["temp"].mean()
# Out:
# 62.9

# %%
df1["temp"].mask()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df1["temp"].mask()
#
# TypeError: NDFrame.mask() missing 1 required positional argument: 'cond'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.set_index("outlook")
# Out:
#          temperature humidity  windy play
# outlook
# overcast         hot     high  False  yes
# overcast        cool   normal   True  yes
# overcast        mild     high   True  yes
# overcast         hot   normal  False  yes
# rainy           mild     high  False  yes
# rainy           cool   normal  False  yes
# rainy           cool   normal   True   no
# rainy           mild   normal  False  yes
# rainy           mild     high   True   no
# sunny            hot     high  False   no
# sunny            hot     high   True   no
# sunny           mild     high  False   no
# sunny           cool   normal  False  yes
# sunny           mild   normal   True  yes

# %%
df.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.set_index("outlook")
# Out:
#          temperature humidity  windy play
# outlook
# overcast         hot     high  False  yes
# overcast        cool   normal   True  yes
# overcast        mild     high   True  yes
# overcast         hot   normal  False  yes
# rainy           mild     high  False  yes
# rainy           cool   normal  False  yes
# rainy           cool   normal   True   no
# rainy           mild   normal  False  yes
# rainy           mild     high   True   no
# sunny            hot     high  False   no
# sunny            hot     high   True   no
# sunny           mild     high  False   no
# sunny           cool   normal  False  yes
# sunny           mild   normal   True  yes

# %%
new_df = df

# %%
new_df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
new_df.set_index("outlook", inplace=True)

# %%
new_df
# Out:
#          temperature humidity  windy play
# outlook
# overcast         hot     high  False  yes
# overcast        cool   normal   True  yes
# overcast        mild     high   True  yes
# overcast         hot   normal  False  yes
# rainy           mild     high  False  yes
# rainy           cool   normal  False  yes
# rainy           cool   normal   True   no
# rainy           mild   normal  False  yes
# rainy           mild     high   True   no
# sunny            hot     high  False   no
# sunny            hot     high   True   no
# sunny           mild     high  False   no
# sunny           cool   normal  False  yes
# sunny           mild   normal   True  yes

# %%
df.loc["overcast"]
# Out:
#          temperature humidity  windy play
# outlook
# overcast         hot     high  False  yes
# overcast        cool   normal   True  yes
# overcast        mild     high   True  yes
# overcast         hot   normal  False  yes

# %%
df
# Out:
#          temperature humidity  windy play
# outlook
# overcast         hot     high  False  yes
# overcast        cool   normal   True  yes
# overcast        mild     high   True  yes
# overcast         hot   normal  False  yes
# rainy           mild     high  False  yes
# rainy           cool   normal  False  yes
# rainy           cool   normal   True   no
# rainy           mild   normal  False  yes
# rainy           mild     high   True   no
# sunny            hot     high  False   no
# sunny            hot     high   True   no
# sunny           mild     high  False   no
# sunny           cool   normal  False  yes
# sunny           mild   normal   True  yes

# %%
del new_df

# %%
new_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 new_df
#
# NameError: name 'new_df' is not defined

# %%
df
# Out:
#          temperature humidity  windy play
# outlook
# overcast         hot     high  False  yes
# overcast        cool   normal   True  yes
# overcast        mild     high   True  yes
# overcast         hot   normal  False  yes
# rainy           mild     high  False  yes
# rainy           cool   normal  False  yes
# rainy           cool   normal   True   no
# rainy           mild   normal  False  yes
# rainy           mild     high   True   no
# sunny            hot     high  False   no
# sunny            hot     high   True   no
# sunny           mild     high  False   no
# sunny           cool   normal  False  yes
# sunny           mild   normal   True  yes

# %%
df.set_index("windy")
# Out:
#       temperature humidity play
# windy
# False         hot     high  yes
# True         cool   normal  yes
# True         mild     high  yes
# False         hot   normal  yes
# False        mild     high  yes
# False        cool   normal  yes
# True         cool   normal   no
# False        mild   normal  yes
# True         mild     high   no
# False         hot     high   no
# True          hot     high   no
# False        mild     high   no
# False        cool   normal  yes
# True         mild   normal  yes

# %%
df = pd.read_csv("Training_Data(CSV-file)/weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
del row, col, data

# %%
print(df, "\n", df1)
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes
#     temp weather
# 0    12    cold
# 1    98   rainy
# 2    64   sunny
# 3    93   sunny
# 4    98    cold
# 5    64   rainy
# 6    73    cold
# 7    36   rainy
# 8    64   sunny
# 9    27   sunny

# %%
del df, df1, test, weathers

# %%
df = pd.read_csv("Training_Data(CSV-file)/weather.csv")

# %%
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df.loc[0]
# Out:
# outlook        overcast
# temperature         hot
# humidity           high
# windy             False
# play                yes
# Name: 0, dtype: object

# %%
py pip freeze
# Out:
#   Cell In[1], line 1
#     py pip freeze
#        ^
# SyntaxError: invalid syntax

# %%
pip freeze
# Out:
# asttokens==2.4.1
# colorama==0.4.6
# comm==0.2.2
# debugpy==1.8.1
# decorator==5.1.1
# executing==2.0.1
# ipykernel==6.29.4
# ipython==8.24.0
# jedi==0.19.1
# jupyter_client==8.6.1
# jupyter_core==5.7.2
# matplotlib-inline==0.1.7
# nest-asyncio==1.6.0
# numpy==1.26.4
# packaging==24.0
# pandas==2.2.2
# parso==0.8.4
# platformdirs==4.2.1
# prompt-toolkit==3.0.43
# psutil==5.9.8
# pure-eval==0.2.2
# Pygments==2.18.0
# python-dateutil==2.9.0.post0
# pytz==2024.1
# pywin32==306
# pyzmq==26.0.3
# six==1.16.0
# stack-data==0.6.3
# tornado==6.4
# traitlets==5.14.3
# typing_extensions==4.11.0
# tzdata==2024.1
# wcwidth==0.2.13
# Note: you may need to restart the kernel to use updated packages.

# %%
pip --version
# Out:
# pip 23.1.2 from e:\playground\python_playgroung_codes\Data_Science\Pandas\pandas-venv\Lib\site-packages\pip (python 3.11)Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("E:\playground\python_playgroung_codes\Data_Science\Pandas\Training_Data(CSV-file)\nyc_weather.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("E:\playground\python_playgroung_codes\Data_Science\Pandas\Training_Data(CSV-file)\nyc_weather.csv")
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("Training_Data(CSV-file)/nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %% [markdown]
# Not the main file go to eda.ipynb complete pandas a should be practiced there
# Thank you 🙏

# %%
# Not the main file go to eda.ipynb complete pandas a should be practiced there
# Thank you 🙏
